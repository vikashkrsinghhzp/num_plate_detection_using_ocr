# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2

# %%
df = pd.read_csv('labels.csv')
df
# Out:
#                     filepath  xmin  xmax  ymin  ymax
# 0    ./label_img/Cars213.xml   150   233   160   194
# 1    ./label_img/Cars207.xml   254   372   229   264
# 2    ./label_img/Cars398.xml    72   196   139   222
# 3    ./label_img/Cars367.xml   224   382   161   222
# 4    ./label_img/Cars401.xml   158   238   223   240
# ..                       ...   ...   ...   ...   ...
# 428  ./label_img/Cars418.xml    99   303    70   155
# 429  ./label_img/Cars395.xml   241   288   182   205
# 430  ./label_img/Cars381.xml    65   147   131   155
# 431  ./label_img/Cars222.xml   178   235   158   170
# 432  ./label_img/Cars236.xml   223   250   106   119
#
# [433 rows x 5 columns]

# %%
df.shape
# Out:
# (433, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filepath  433 non-null    object
#  1   xmin      433 non-null    int64
#  2   xmax      433 non-null    int64
#  3   ymin      433 non-null    int64
#  4   ymax      433 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 17.0+ KB

# %%
df.columns
# Out:
# Index(['filepath', 'xmin', 'xmax', 'ymin', 'ymax'], dtype='object')

# %%
df.describe()
# Out:
#              xmin        xmax        ymin        ymax
# count  433.000000  433.000000  433.000000  433.000000
# mean   165.780600  268.778291  161.870670  198.720554
# std     82.698837   92.338181   54.059183   51.698225
# min      0.000000   27.000000    5.000000   65.000000
# 25%    110.000000  218.000000  127.000000  163.000000
# 50%    156.000000  261.000000  163.000000  195.000000
# 75%    213.000000  319.000000  192.000000  226.000000
# max    541.000000  598.000000  405.000000  439.000000

# %%
df.head(5)
# Out:
#                   filepath  xmin  xmax  ymin  ymax
# 0  ./label_img/Cars213.xml   150   233   160   194
# 1  ./label_img/Cars207.xml   254   372   229   264
# 2  ./label_img/Cars398.xml    72   196   139   222
# 3  ./label_img/Cars367.xml   224   382   161   222
# 4  ./label_img/Cars401.xml   158   238   223   240

# %%
#to get the file name
import xml.etree.ElementTree as xet

# %%
filename = df['filepath'][0]
filename
# Out:
# './label_img/Cars213.xml'

# %%
xet.parse(filename).getroot().find('filename').text
# Out:
# 'Cars213.png'

# %%
#function to get filename
def getFilename(filename):
    filename_image = xet.parse(filename).getroot().find('filename').text
    filepath_image = os.path.join('/label_img',filename_image)
    return filepath_image

# %%
getFilename(filename)
# Out:
# '/label_img/Cars213.png'

# %%
df['filepath'].apply(getFilename)
# Out:
# 0      /label_img/Cars213.png
# 1      /label_img/Cars207.png
# 2      /label_img/Cars398.png
# 3      /label_img/Cars367.png
# 4      /label_img/Cars401.png
#                 ...
# 428    /label_img/Cars418.png
# 429    /label_img/Cars395.png
# 430    /label_img/Cars381.png
# 431    /label_img/Cars222.png
# 432    /label_img/Cars236.png
# Name: filepath, Length: 433, dtype: object

# %%
image_path = list(df['filepath'].apply(getFilename))
image_path
#here we get all the images path
# Out:
# ['/label_img/Cars213.png',
#  '/label_img/Cars207.png',
#  '/label_img/Cars398.png',
#  '/label_img/Cars367.png',
#  '/label_img/Cars401.png',
#  '/label_img/Cars415.png',
#  '/label_img/Cars373.png',
#  '/label_img/Cars429.png',
#  '/label_img/Cars47.png',
#  '/label_img/Cars53.png',
#  '/label_img/Cars165.png',
#  '/label_img/Cars171.png',
#  '/label_img/Cars159.png',
#  '/label_img/Cars84.png',
#  '/label_img/Cars90.png',
#  '/label_img/Cars91.png',
#  '/label_img/Cars85.png',
#  '/label_img/Cars158.png',
#  '/label_img/Cars170.png',
#  '/label_img/Cars164.png',
#  '/label_img/Cars52.png',
#  '/label_img/Cars46.png',
#  '/label_img/Cars428.png',
#  '/label_img/Cars414.png',
#  '/label_img/Cars372.png',
#  '/label_img/Cars366.png',
#  '/label_img/Cars400.png',
#  '/label_img/Cars399.png',
#  '/label_img/Cars206.png',
#  '/label_img/Cars212.png',
#  '/label_img/Cars204.png',
#  '/label_img/Cars210.png',
#  '/label_img/Cars238.png',
#  '/label_img/Cars370.png',
# ...

# %% [markdown]
# ## Verify Images and Its Output

# %%
file_path = image_path[0]
file_path
# Out:
# '/label_img/Cars213.png'

# %%
# # img = cv2.imread(file_path)
# img = cv2.imread('/Users/vikash/Project/Number Plate Detection using OCR/label_img/Cars213.png')
# # cv2.namedWindow('example', cv2.WINDOW_NORMAL)
# cv2.imshow('example',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# #Draw the boundary box for 150	233	160	194

# cv2.rectangle(img,(150,160),(233,194),(0,255,0),3)

# #(0,255,0) used for green color
# #3 is used for thickness

# cv2.namedWindow('example', cv2.WINDOW_NORMAL)
# cv2.imshow('example',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Data Processing

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
